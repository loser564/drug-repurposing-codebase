# %%
import os
import textwrap
from typing import List, Dict, Set, Any
from Bio import Entrez
from time import sleep
import json
import yaml  
import pandas as pd
import re

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### get list of drug names

# %%
def load_config(yaml_path="P2-config.yaml"):
    with open(yaml_path, "r", encoding="utf-8") as f:
        return yaml.safe_load(f)
    
config = load_config()

all_drugs_path = config["all_drugs"]
all_drugs = pd.read_csv(all_drugs_path)
drug_names = all_drugs['DRUGNAME'].dropna().astype(str).unique().tolist()

drug_names_file = config["drug_names_file"]

with open(drug_names_file, "w", encoding="utf-8") as f:
    for name in drug_names:
        f.write(name + "\n")

# %%
class NCBIMeSHScraper:
    def __init__(self, email: str, config: Dict[str, Any]):
        self.email = email
        self.config = config

        Entrez.email = self.email
        Entrez.tool = "DrugPathwayAnalyzer"

        self.api_key = os.getenv("NCBI_API_KEY")
        if self.api_key:
            Entrez.api_key = self.api_key
            print("[INFO] NCBI API key loaded.")
        else:
            print("[WARN] NCBI_API_KEY not found. Continuing without key (stricter rate limits).")

    def _make_or_block(self, terms: List[str]) -> str:
        """
        ["foo", "bar baz"] -> '("foo" OR "bar baz")'
        Assumes terms are already quoted if needed.
        """
        clean_terms = [t.strip() for t in terms if t.strip()]
        if not clean_terms:
            return ""
        if len(clean_terms) == 1:
            return clean_terms[0]
        return "(" + " OR ".join(clean_terms) + ")"

    def search_pubmed(self, query: str, retmax: int = 50) -> List[str]:
        handle = Entrez.esearch(
            db="pubmed",
            term=query,
            retmax=retmax,
        )
        rec = Entrez.read(handle)
        handle.close()
        return rec.get("IdList", [])

    def fetch_pubmed_mesh(self, pmids: List[str]) -> Dict[str, List[str]]:
        """
        Returns { pmid: [mesh_term1, mesh_term2, ...], ... }
        """
        mesh_by_pmid: Dict[str, List[str]] = {}
        if not pmids:
            return mesh_by_pmid

        BATCH = 50
        for i in range(0, len(pmids), BATCH):
            batch_ids = pmids[i:i+BATCH]
            handle = Entrez.efetch(
                db="pubmed",
                id=",".join(batch_ids),
                retmode="xml"
            )
            records = Entrez.read(handle)
            handle.close()

            for article in records.get("PubmedArticle", []):
                # PMID
                pmid = None
                try:
                    pmid_val = article["MedlineCitation"]["PMID"]
                    pmid = (
                        pmid_val.get("#text", pmid_val)
                        if isinstance(pmid_val, dict) else pmid_val
                    )
                except KeyError:
                    pmid = None

                # MeSH terms list
                mesh_terms = []
                try:
                    mh_list = article["MedlineCitation"]["MeshHeadingList"]
                    for mh in mh_list:
                        desc = mh.get("DescriptorName")
                        if isinstance(desc, dict):
                            term_text = desc.get("#text", "")
                        else:
                            term_text = str(desc)
                        term_text = term_text.strip()
                        if term_text:
                            mesh_terms.append(term_text)
                except KeyError:
                    pass

                if pmid:
                    mesh_by_pmid[pmid] = mesh_terms

            # be polite if no key
            sleep(0.34)

        return mesh_by_pmid

    def get_joint_mesh_for_drug(
        self,
        drug_name: str,
        disease_blocks: List[Dict[str, Any]],
        therapy_terms: List[str],
        retmax: int = 50,
    ) -> Dict[str, Any]:
        """
        Generic version:
        - disease_blocks: list of disease configs, each with:
            - id (str)
            - label (str)
            - query_terms (List[str])
            - mesh_match_substrings (List[str])
        - therapy_terms: extra PubMed filter terms (e.g. ["\"drug therapy\""])
        """

        # Build per-disease OR blocks for PubMed
        disease_query_blocks = []
        for d in disease_blocks:
            q_terms = d.get("query_terms", [])
            disease_query_blocks.append(self._make_or_block(q_terms))

        therapy_block = self._make_or_block(therapy_terms)

        # Build the combined PubMed query
        query_parts = [f"\"{drug_name}\"[Title/Abstract]"]
        for dq in disease_query_blocks:
            if dq:
                query_parts.append(dq)
        if therapy_block:
            query_parts.append(therapy_block)

        query = " AND ".join(query_parts)

        pmids = self.search_pubmed(query, retmax=retmax)
        mesh_map = self.fetch_pubmed_mesh(pmids)

        # all MeSH terms across joint PMIDs
        all_mesh_terms: Set[str] = set(
            term for terms in mesh_map.values() for term in terms
        )

        # classify MeSH into per-disease buckets based on substrings
        disease_results = []
        for d in disease_blocks:
            d_id = d.get("id", "unknown")
            d_label = d.get("label", d_id)
            match_subs = d.get("mesh_match_substrings", [])

            hits = sorted({
                t for t in all_mesh_terms
                if any(sub in t for sub in match_subs)
            }) if match_subs else []

            disease_results.append({
                "id": d_id,
                "label": d_label,
                "query_terms": d.get("query_terms", []),
                "mesh_match_substrings": match_subs,
                "mesh_hits": hits,
            })

        # joint signal requires at least one hit for every disease
        has_joint_signal = bool(pmids) and all(
            len(d["mesh_hits"]) > 0 for d in disease_results
        )

        return {
            "drug": drug_name,
            "query": query,
            "pmids_joint": pmids,
            "mesh_terms_joint": sorted(all_mesh_terms),
            "diseases": disease_results,
            "has_joint_signal": has_joint_signal,
        }

    # ------------------------------------------------------------------
    # Pretty report generator
    # ------------------------------------------------------------------

    def _wrap_line(self, s: str, width: int = 100) -> str:
        return '\n'.join(textwrap.fill(
            s,
            width=width,
            replace_whitespace=False,
            break_long_words=False,
            break_on_hyphens=False
        ).splitlines())

    def generate_user_friendly_report(self, analysis: Dict[str, Any]) -> str:
        """
        Turn a single drug analysis dict (from get_joint_mesh_for_drug)
        into a human-readable multi-section text block.
        Supports an arbitrary number of diseases (from config).
        """

        drug_name = analysis["drug"]
        pmids = analysis["pmids_joint"]
        all_mesh = analysis["mesh_terms_joint"]
        diseases = analysis.get("diseases", [])
        has_joint = analysis.get("has_joint_signal", False)

        # If zero PMIDs, just say nothing found.
        if not pmids:
            disease_labels = [d["label"] for d in diseases] if diseases else ["the configured diseases"]
            disease_str = " and ".join(disease_labels)
            return (
                f"DRUG PATHWAY ANALYSIS REPORT: {drug_name.upper()}\n"
                f"----------------------------------------------------------------------------\n"
                f"No PubMed articles were found that mention {drug_name} together with BOTH\n"
                f"{disease_str} in the same query.\n"
            )

        out_lines: List[str] = []

        out_lines.append("=" * 80)
        out_lines.append(f"DRUG PATHWAY ANALYSIS REPORT: {drug_name.upper()}")
        out_lines.append("=" * 80)
        out_lines.append("")

        # 1. SUMMARY
        out_lines.append("SUMMARY")
        out_lines.append("-" * 80)
        out_lines.append(f"Total joint-hit PMIDs: {len(pmids)}")
        out_lines.append(f"Dual-indication signal detected? {'YES' if has_joint else 'NO'}")
        out_lines.append("")
        out_lines.append("PubMed Boolean query used:")
        out_lines.append(self._wrap_line(analysis["query"]))
        out_lines.append("")

        # 2. MESH EVIDENCE
        out_lines.append("MESH EVIDENCE (DISEASE AREAS)")
        out_lines.append("-" * 80)
        for d in diseases:
            out_lines.append(f"{d['label']} MeSH terms observed in these same PMIDs:")
            hits = d.get("mesh_hits", [])
            if hits:
                for term in hits:
                    out_lines.append(f"  - {term}")
            else:
                out_lines.append("  (none)")
            out_lines.append("")

        # 3. ALL MESH TERMS
        out_lines.append("ALL UNIQUE MeSH TERMS FROM JOINT-HIT ARTICLES")
        out_lines.append("-" * 80)
        for term in all_mesh:
            out_lines.append("  - " + term)

        out_lines.append("")

        # 4. PMIDs
        out_lines.append("SUPPORTING PMIDs")
        out_lines.append("-" * 80)
        pmid_chunks = [pmids[i:i+10] for i in range(0, len(pmids), 10)]
        for chunk in pmid_chunks:
            line = ", ".join(chunk)
            out_lines.append("  " + line)

        out_lines.append("")
        out_lines.append("INTERPRETATION")
        out_lines.append("-" * 80)

        disease_labels = [d["label"] for d in diseases]
        disease_str = " and ".join(disease_labels) if disease_labels else "the configured diseases"

        if has_joint:
            out_lines.append(
                self._wrap_line(
                    f"These PubMed articles simultaneously reference the drug and biological "
                    f"contexts related to {disease_str}. The MeSH labeling suggests that "
                    f"researchers are discussing this drug in a setting that touches multiple "
                    f"disease areas. This is a strong multi-indication signal, but does not "
                    f"prove therapeutic efficacy."
                )
            )
        else:
            out_lines.append(
                self._wrap_line(
                    f"Although PubMed returned articles where the drug and the configured "
                    f"disease-related terms co-occur in the same query, the MeSH annotations "
                    f"did not clearly include all disease areas together. This weakens confidence "
                    f"that the drug is being studied directly in a multi-indication context."
                )
            )

        return "\n".join(out_lines)

# %%
if __name__ == "__main__":
    # --- load config from YAML ---

    config = load_config()


    ncbi_cfg = config.get("ncbi", {})
    email = os.getenv("NCBI_EMAIL")

    scraper = NCBIMeSHScraper(email=email, config=config)
    drug_names_file = config["drug_names_file"]

    # Iterate over all disease pairs defined in YAML
    for pair_cfg in config.get("disease_pairs", []):
        pair_name = pair_cfg.get("name", "unnamed_pair")
        print(f"\n=== Running disease pair: {pair_name} ===")

        
        reports_dir = pair_cfg["reports_dir"]
        results_json = pair_cfg["results_json"]
        retmax = pair_cfg.get("retmax", 50)
        sleep_between_drugs = pair_cfg.get("sleep_between_drugs", 0.5)
        therapy_terms = pair_cfg.get("therapy_terms", [])
        disease_blocks = pair_cfg["diseases"]

        # load the drug list
        with open(drug_names_file, "r", encoding="utf-8") as f:
            drug_names = [line.strip() for line in f if line.strip()]

        # os.makedirs(reports_dir, exist_ok=True)

        results = []
        for drug in drug_names:
            print(f"[CHECK] {drug}")
            analysis = scraper.get_joint_mesh_for_drug(
                drug_name=drug,
                disease_blocks=disease_blocks,
                therapy_terms=therapy_terms,
                retmax=retmax,
            )
            results.append(analysis)
            sleep(sleep_between_drugs)


 
            report_txt = scraper.generate_user_friendly_report(analysis)
            safe_name = drug.replace("/", "_").replace(" ", "_")
            print(safe_name)
            report_path = os.path.join(reports_dir, f"{safe_name}_report.txt")
            with open(report_path, "w", encoding="utf-8") as rf:
                rf.write(report_txt)

        # console summary of which drugs look promising
        print("\n=== DRUGS WITH DIRECT JOINT SIGNAL (MESH CONFIRMED) ===")
        for r in results:
            if r["has_joint_signal"]:
                print(f"- {r['drug']} ({len(r['pmids_joint'])} PMIDs)")

        # dump raw JSON for downstream ML
        with open(results_json, "w", encoding="utf-8") as fh:
            json.dump(results, fh, indent=2)
        print(f"[OK] wrote {results_json} and individual text reports in {reports_dir}/")
# Out:
# [INFO] NCBI API key loaded.
#
# === Running disease pair: diabetes_crc ===
# [CHECK] Pemigatinib
# Pemigatinib
# [CHECK] Intedanib
# Intedanib
# [CHECK] Romiplostim
# Romiplostim
# [CHECK] Necitumumab
# Necitumumab
# [CHECK] HEGF
# HEGF
# [CHECK] Erlotinib
# Erlotinib
# [CHECK] Gefitinib
# Gefitinib
# [CHECK] Panitumumab
# Panitumumab
# [CHECK] Cetuximab
# Cetuximab
# [CHECK] BIBW 2992
# BIBW_2992
# [CHECK] Nitroglycerin
# Nitroglycerin
# [CHECK] Epidermal growth factor
# Epidermal_growth_factor
# [CHECK] Osimertinib
# Osimertinib
# [CHECK] NERATINIB MALEATE
# NERATINIB_MALEATE
# [CHECK] Amivantamab
# Amivantamab
# [CHECK] SKI-758
# SKI-758
# [CHECK] Dacomitinib
# Dacomitinib
# [CHECK] Lapatinib
# Lapatinib
# [CHECK] Merimepodib
# Merimepodib
# [CHECK] Vandetanib
# Vandetanib
# [CHECK] Sorafenib
# Sorafenib
# [CHECK] Adenosine triphosphate
# Adenosine_triphosphate
# [CHECK] Bosutinib
# Bosutinib
# [CHECK] Ponatinib
# Ponatinib
# [CHECK] Estrone
# Estrone
# [CHECK] Conjugated estrogens b
# Conjugated_estrogens_b
# [CHECK] Raloxifene
# Raloxifene
# [CHECK] Ospemifene
# Ospemifene
# [CHECK] Estropipate
# Estropipate
# [CHECK] Quinestrol
# Quinestrol
# [CHECK] Toremifene
# Toremifene
# [CHECK] Ethinyl Estradiol
# Ethinyl_Estradiol
# [CHECK] Tamoxifen
# Tamoxifen
# [CHECK] Elacestrant
# Elacestrant
# [CHECK] Estradiol Valerate
# Estradiol_Valerate
# [CHECK] Estradiol
# Estradiol
# [CHECK] Danazol
# Danazol
# [CHECK] Dienestrol
# Dienestrol
# [CHECK] Conjugated estrogens a
# Conjugated_estrogens_a
# [CHECK] Promestriene
# Promestriene
# [CHECK] Clomifene
# Clomifene
# [CHECK] Clomiphene Citrate
# Clomiphene_Citrate
# [CHECK] Mestranol
# Mestranol
# [CHECK] Fulvestrant
# Fulvestrant
# [CHECK] Fosfestrol
# Fosfestrol
# [CHECK] Bazedoxifene
# Bazedoxifene
# [CHECK] Gestrinone
# Gestrinone
# [CHECK] Cenestin
# Cenestin
# [CHECK] Esterified estrogens
# Esterified_estrogens
# [CHECK] Premarin/Trimegestone
# Premarin_Trimegestone
# [CHECK] Estradiol Acetate
# Estradiol_Acetate
# [CHECK] Estradiol Cypionate
# Estradiol_Cypionate
# [CHECK] Nomegestrol acetate
# Nomegestrol_acetate
# [CHECK] Levormeloxifene
# Levormeloxifene
# [CHECK] Cyclofenil
# Cyclofenil
# [CHECK] Diethylstilbestrol
# Diethylstilbestrol
# [CHECK] Estriol
# Estriol
# [CHECK] Mitotane
# Mitotane
# [CHECK] ARZOXIFENE
# ARZOXIFENE
# [CHECK] Lasofoxifene
# Lasofoxifene
# [CHECK] Estrogen
# Estrogen
# [CHECK] Trilostane
# Trilostane
# [CHECK] Conjugated Estrogens
# Conjugated_Estrogens
# [CHECK] Human neutral insulin
# Human_neutral_insulin
# [CHECK] Insulin Lyspro recombinant
# Insulin_Lyspro_recombinant
# [CHECK] Insulin, porcine
# Insulin,_porcine
# [CHECK] Insulin recombinant
# Insulin_recombinant
# [CHECK] Metformin arginine-hemisuccinimide
# Metformin_arginine-hemisuccinimide
# [CHECK] Insulin-lispro
# Insulin-lispro
# [CHECK] Insulin-glulisine
# Insulin-glulisine
# [CHECK] Ryzodeq
# Ryzodeq
# [CHECK] Meglitinides
# Meglitinides
# [CHECK] Dabrafenib
# Dabrafenib
# [CHECK] LGX818
# LGX818
# [CHECK] Vemurafenib
# Vemurafenib
# [CHECK] Olaratumab
# Olaratumab
# [CHECK] Avapritinib
# Avapritinib
# [CHECK] Ripretinib
# Ripretinib
# [CHECK] Interferon Alfa-2a, Recombinant
# Interferon_Alfa-2a,_Recombinant
# [CHECK] Palifermin
# Palifermin
# [CHECK] YM443
# YM443
# [CHECK] Ambenonium
# Ambenonium
# [CHECK] Demecarium bromide
# Demecarium_bromide
# [CHECK] Neostigmine
# Neostigmine
# [CHECK] Isoflurophate
# Isoflurophate
# [CHECK] Tacrine
# Tacrine
# [CHECK] Malathion
# Malathion
# [CHECK] Donepezil
# Donepezil
# [CHECK] Pyridostigmine
# Pyridostigmine
# [CHECK] Galantamine
# Galantamine
# [CHECK] Edrophonium
# Edrophonium
# [CHECK] Echothiophate Iodide
# Echothiophate_Iodide
# [CHECK] Rivastigmine
# Rivastigmine
# [CHECK] Pralidoxime Chloride
# Pralidoxime_Chloride
# [CHECK] Huperzine A
# Huperzine_A
# [CHECK] Axitinib
# Axitinib
# [CHECK] Ramucirumab
# Ramucirumab
# [CHECK] Lenvatinib
# Lenvatinib
# [CHECK] Sunitinib
# Sunitinib
# [CHECK] YN-968D1
# YN-968D1
# [CHECK] Cabozantinib
# Cabozantinib
# [CHECK] Regorafenib
# Regorafenib
# [CHECK] Pazopanib HCl
# Pazopanib_HCl
# [CHECK] Tivozanib
# Tivozanib
# [CHECK] Novolimus
# Novolimus
# [CHECK] Temsirolimus
# Temsirolimus
# [CHECK] Everolimus
# Everolimus
# [CHECK] Zotarolimus
# Zotarolimus
# [CHECK] Sirolimus
# Sirolimus
# [CHECK] PF-04449913
# PF-04449913
# [CHECK] Ibrutinib
# Ibrutinib
# [CHECK] Acalabrutinib
# Acalabrutinib
# [CHECK] Zanubrutinib
# Zanubrutinib
# [CHECK] Pirtobrutinib
# Pirtobrutinib
# [CHECK] Panobinostat
# Panobinostat
# [CHECK] Vorinostat
# Vorinostat
# [CHECK] Romidepsin
# Romidepsin
# [CHECK] Naftifine
# Naftifine
# [CHECK] Tolnaftate
# Tolnaftate
# [CHECK] Isoxyl
# Isoxyl
# [CHECK] Recombinant Factor IX
# Recombinant_Factor_IX
# [CHECK] Emicizumab
# Emicizumab
# [CHECK] Ranolazine
# Ranolazine
# [CHECK] Streptokinase
# Streptokinase
# [CHECK] Tranexamic Acid
# Tranexamic_Acid
# [CHECK] Alteplase
# Alteplase
# [CHECK] Tenecteplase
# Tenecteplase
# [CHECK] Anistreplase
# Anistreplase
# [CHECK] Reteplase
# Reteplase
# [CHECK] Aminocaproic Acid
# Aminocaproic_Acid
# [CHECK] Pro-urokinase
# Pro-urokinase
# [CHECK] Urokinase
# Urokinase
# [CHECK] Miltefosine
# Miltefosine
# [CHECK] Clocortolone
# Clocortolone
# [CHECK] Clobetasol
# Clobetasol
# [CHECK] Diflorasone
# Diflorasone
# [CHECK] Cholic Acid
# Cholic_Acid
# [CHECK] Difluprednate
# Difluprednate
# [CHECK] Fluocinolone Acetonide
# Fluocinolone_Acetonide
# [CHECK] Triamcinolone
# Triamcinolone
# [CHECK] Mometasone
# Mometasone
# [CHECK] Betamethasone Valerate
# Betamethasone_Valerate
# [CHECK] Hydrocortamate
# Hydrocortamate
# [CHECK] Betamethasone Benzoate
# Betamethasone_Benzoate
# [CHECK] Methylprednisolone
# Methylprednisolone
# [CHECK] Deflazacort
# Deflazacort
# [CHECK] Betamethasone
# Betamethasone
# [CHECK] Prednisolone
# Prednisolone
# [CHECK] Flunisolide
# Flunisolide
# [CHECK] Meprednisone
# Meprednisone
# [CHECK] Prednisone
# Prednisone
# [CHECK] Dexamethasone
# Dexamethasone
# [CHECK] Hydrocortisone
# Hydrocortisone
# [CHECK] Fluticasone
# Fluticasone
# [CHECK] Dexamethasone sodium phosphate
# Dexamethasone_sodium_phosphate
# [CHECK] Fluorometholone
# Fluorometholone
# [CHECK] Budesonide
# Budesonide
# [CHECK] GW685698X
# GW685698X
# [CHECK] Mifepristone
# Mifepristone
# [CHECK] Vamorolone
# Vamorolone
# [CHECK] Factor viia
# Factor_viia
# [CHECK] Factor 8
# Factor_8
# [CHECK] Eloctate
# Eloctate
# [CHECK] Efanesoctocog alfa
# Efanesoctocog_alfa
# [CHECK] Drotrecogin alfa
# Drotrecogin_alfa
# [CHECK] Tranilast
# Tranilast
# [CHECK] Becaplermin
# Becaplermin
# [CHECK] Bestatin
# Bestatin
# [CHECK] Nandrolone
# Nandrolone
# [CHECK] Cyproterone
# Cyproterone
# [CHECK] Testosterone
# Testosterone
# [CHECK] Clascoterone
# Clascoterone
# [CHECK] Dromostanolone
# Dromostanolone
# [CHECK] Hydroxyflutamide
# Hydroxyflutamide
# [CHECK] Darolutamide
# Darolutamide
# [CHECK] Fluoxymesterone
# Fluoxymesterone
# [CHECK] Enzalutamide
# Enzalutamide
# [CHECK] ARN-509
# ARN-509
# [CHECK] Ethylestrenol
# Ethylestrenol
# [CHECK] Nilutamide
# Nilutamide
# [CHECK] Oxandrolone
# Oxandrolone
# [CHECK] Bicalutamide
# Bicalutamide
# [CHECK] Flutamide
# Flutamide
# [CHECK] Prasterone
# Prasterone
# [CHECK] Fludrocortisone
# Fludrocortisone
# [CHECK] Flufenamic Acid
# Flufenamic_Acid
# [CHECK] Calcipotriol
# Calcipotriol
# [CHECK] Falecalcitrol
# Falecalcitrol
# [CHECK] Calcidiol
# Calcidiol
# [CHECK] Ergocalciferol
# Ergocalciferol
# [CHECK] Doxercalciferol
# Doxercalciferol
# [CHECK] Dihydrotachysterol
# Dihydrotachysterol
# [CHECK] Cholecalciferol
# Cholecalciferol
# [CHECK] Paricalcitol
# Paricalcitol
# [CHECK] Calcitriol
# Calcitriol
# [CHECK] Letrozole
# Letrozole
# [CHECK] Testolactone
# Testolactone
# [CHECK] Exemestane
# Exemestane
# [CHECK] Anastrozole
# Anastrozole
# [CHECK] Aminoglutethimide
# Aminoglutethimide
# [CHECK] FADROZOLE
# FADROZOLE
# [CHECK] Palbociclib
# Palbociclib
# [CHECK] Ribociclib Succinate
# Ribociclib_Succinate
# [CHECK] LY2835219
# LY2835219
# [CHECK] Trilaciclib
# Trilaciclib
# [CHECK] Apremilast
# Apremilast
# [CHECK] Eflornithine
# Eflornithine
# [CHECK] Moexipril
# Moexipril
# [CHECK] Enalapril
# Enalapril
# [CHECK] Ramipril
# Ramipril
# [CHECK] Temocapril hydrochloride
# Temocapril_hydrochloride
# [CHECK] Perindopril
# Perindopril
# [CHECK] Cilazapril
# Cilazapril
# [CHECK] Spirapril
# Spirapril
# [CHECK] Lisinopril
# Lisinopril
# [CHECK] Deserpidine
# Deserpidine
# [CHECK] Rescinnamine
# Rescinnamine
# [CHECK] Delapril
# Delapril
# [CHECK] Captopril
# Captopril
# [CHECK] Quinapril
# Quinapril
# [CHECK] Trandolapril
# Trandolapril
# [CHECK] Enalaprilat
# Enalaprilat
# [CHECK] Imidapril
# Imidapril
# [CHECK] Benazepril
# Benazepril
# [CHECK] Hydrochlorothiazide
# Hydrochlorothiazide
# [CHECK] Alacepril
# Alacepril
# [CHECK] Fosinopril
# Fosinopril
# [CHECK] Antegren
# Antegren
# [CHECK] Natalizumab
# Natalizumab
# [CHECK] Vedolizmab
# Vedolizmab
# [CHECK] MLN0002
# MLN0002
# [CHECK] Tromethamine
# Tromethamine
# [CHECK] Uridine
# Uridine
# [CHECK] Methscopolamine Bromide
# Methscopolamine_Bromide
# [CHECK] LAS-34273
# LAS-34273
# [CHECK] Tolterodine
# Tolterodine
# [CHECK] Solifenacin
# Solifenacin
# [CHECK] Cevimeline
# Cevimeline
# [CHECK] Succinylcholine
# Succinylcholine
# [CHECK] Ipratropium
# Ipratropium
# [CHECK] Tiotropium
# Tiotropium
# [CHECK] Darifenacin
# Darifenacin
# [CHECK] Methacholine Chloride
# Methacholine_Chloride
# [CHECK] SMT-D002
# SMT-D002
# [CHECK] Methylscopolamine
# Methylscopolamine
# [CHECK] ACECLIDINE
# ACECLIDINE
# [CHECK] Vitamin B6
# Vitamin_B6
# [CHECK] Carbidopa
# Carbidopa
# [CHECK] Ozanimod
# Ozanimod
# [CHECK] Fingolimod
# Fingolimod
# [CHECK] Etrasimod
# Etrasimod
# [CHECK] Ponesimod
# Ponesimod
# [CHECK] Siponimod
# Siponimod
# [CHECK] Piroxicam
# Piroxicam
# [CHECK] Suprofen
# Suprofen
# [CHECK] Balsalazide
# Balsalazide
# [CHECK] Mesalazine
# Mesalazine
# [CHECK] Gamma-Homolinolenic acid
# Gamma-Homolinolenic_acid
# [CHECK] Bromfenac
# Bromfenac
# [CHECK] Salsalate
# Salsalate
# [CHECK] FENBUFEN
# FENBUFEN
# [CHECK] Naproxen
# Naproxen
# [CHECK] Meclofenamate Sodium
# Meclofenamate_Sodium
# [CHECK] Eicosapentaenoic acid/docosa-hexaenoic acid
# Eicosapentaenoic_acid_docosa-hexaenoic_acid
# [CHECK] Aminosalicylic Acid
# Aminosalicylic_Acid
# [CHECK] Salicyclic acid
# Salicyclic_acid
# [CHECK] Urofollitropin
# Urofollitropin
# [CHECK] Menotropins
# Menotropins
# [CHECK] Follitropin beta
# Follitropin_beta
# [CHECK] Linagliptin
# Linagliptin
# [CHECK] Kombiglyze XR/Komboglyze FDC
# Kombiglyze_XR_Komboglyze_FDC
# [CHECK] Saxagliptin
# Saxagliptin
# [CHECK] Vildagliptin
# Vildagliptin
# [CHECK] Alogliptin
# Alogliptin
# [CHECK] Anagliptin
# Anagliptin
# [CHECK] Sitagliptin
# Sitagliptin
# [CHECK] Dapagliflozin Propanediol; Saxagliptin Hydrochloride
# Dapagliflozin_Propanediol;_Saxagliptin_Hydrochloride
# [CHECK] Pentagastrin
# Pentagastrin
# [CHECK] Ceruletide
# Ceruletide
# [CHECK] Setmelanotide
# Setmelanotide
# [CHECK] Methylnaltrexone bromide
# Methylnaltrexone_bromide
# [CHECK] Bremelanotide
# Bremelanotide
# [CHECK] Sulfinpyrazone
# Sulfinpyrazone
# [CHECK] Benzbromarone
# Benzbromarone
# [CHECK] NABILONE
# NABILONE
# [CHECK] Guanfacine extended release
# Guanfacine_extended_release
# [CHECK] Carbinoxamine
# Carbinoxamine
# [CHECK] Azelastine
# Azelastine
# [CHECK] Cyproheptadine
# Cyproheptadine
# [CHECK] Desloratadine
# Desloratadine
# [CHECK] Fexofenadine
# Fexofenadine
# [CHECK] Mepyramine maleate
# Mepyramine_maleate
# [CHECK] Dexbrompheniramine
# Dexbrompheniramine
# [CHECK] Emedastine
# Emedastine
# [CHECK] Buclizine
# Buclizine
# [CHECK] Pheniramine
# Pheniramine
# [CHECK] Ergotidine
# Ergotidine
# [CHECK] Olopatadine
# Olopatadine
# [CHECK] Dexchlorpheniramine Maleate
# Dexchlorpheniramine_Maleate
# [CHECK] Loratadine
# Loratadine
# [CHECK] Aceprometazine
# Aceprometazine
# [CHECK] Doxepin
# Doxepin
# [CHECK] Antazoline
# Antazoline
# [CHECK] Mizolastine
# Mizolastine
# [CHECK] Phenindamine
# Phenindamine
# [CHECK] Dimethindene
# Dimethindene
# [CHECK] Cyclizine
# Cyclizine
# [CHECK] Trimeprazine
# Trimeprazine
# [CHECK] Mepyramine
# Mepyramine
# [CHECK] Levocabastine
# Levocabastine
# [CHECK] Brompheniramine
# Brompheniramine
# [CHECK] Mequitazine
# Mequitazine
# [CHECK] Oxatomide
# Oxatomide
# [CHECK] Tripelennamine
# Tripelennamine
# [CHECK] Chlorpheniramine
# Chlorpheniramine
# [CHECK] Clemastine
# Clemastine
# [CHECK] Cetirizine
# Cetirizine
# [CHECK] Epinastine
# Epinastine
# [CHECK] Triprolidine
# Triprolidine
# [CHECK] Chlophedianol
# Chlophedianol
# [CHECK] Pemirolast
# Pemirolast
# [CHECK] Methdilazine
# Methdilazine
# [CHECK] Levocetirizine dihydrochloride
# Levocetirizine_dihydrochloride
# [CHECK] Azatadine
# Azatadine
# [CHECK] Acrivastine
# Acrivastine
# [CHECK] Hydroxyzine
# Hydroxyzine
# [CHECK] Alcaftadine
# Alcaftadine
# [CHECK] Ethopropazine
# Ethopropazine
# [CHECK] Cinnarizine
# Cinnarizine
# [CHECK] Propiomazine
# Propiomazine
# [CHECK] Promethazine
# Promethazine
# [CHECK] Bepotastine
# Bepotastine
# [CHECK] Dimenhydrinate
# Dimenhydrinate
# [CHECK] Diphenylpyraline
# Diphenylpyraline
# [CHECK] Doxylamine
# Doxylamine
# [CHECK] Bromodiphenhydramine
# Bromodiphenhydramine
# [CHECK] Ketotifen
# Ketotifen
# [CHECK] (S)-(+)-Dimethindene maleate
# (S)-(+)-Dimethindene_maleate
# [CHECK] Diphenhydramine
# Diphenhydramine
# [CHECK] Pioglitazone
# Pioglitazone
# [CHECK] Troglitazone
# Troglitazone
# [CHECK] Rosiglitazone XR
# Rosiglitazone_XR
# [CHECK] Thiazolidinedione
# Thiazolidinedione
# [CHECK] Lobeglitazone
# Lobeglitazone
# [CHECK] Fostamatinib
# Fostamatinib
# [CHECK] Melatonin
# Melatonin
# [CHECK] Tasimelteon
# Tasimelteon
# [CHECK] Ramelteon
# Ramelteon
# [CHECK] Valproate
# Valproate
# [CHECK] Maraviroc
# Maraviroc
# [CHECK] Bezafibrate
# Bezafibrate
# [CHECK] Pemafibrate
# Pemafibrate
# [CHECK] Fenofibrate
# Fenofibrate
# [CHECK] Ciprofibrate
# Ciprofibrate
# [CHECK] Larotrectinib
# Larotrectinib
# [CHECK] Entrectinib
# Entrectinib
# [CHECK] Vismodegib
# Vismodegib
# [CHECK] Ceritinib
# Ceritinib
# [CHECK] Brigatinib
# Brigatinib
# [CHECK] Alectinib
# Alectinib
# [CHECK] Lorlatinib
# Lorlatinib
# [CHECK] Crizotinib
# Crizotinib
# [CHECK] Metformin
# Metformin
# [CHECK] Trimethoprim
# Trimethoprim
# [CHECK] Leucovorin Calcium
# Leucovorin_Calcium
# [CHECK] Methotrexate Sodium
# Methotrexate_Sodium
# [CHECK] Elapegademase
# Elapegademase
# [CHECK] Cladribine
# Cladribine
# [CHECK] Fludarabine
# Fludarabine
# [CHECK] Pentostatin
# Pentostatin
# [CHECK] Enbrel
# Enbrel
# [CHECK] Golimumab
# Golimumab
# [CHECK] Pentoxifylline
# Pentoxifylline
# [CHECK] Certolizumab
# Certolizumab
# [CHECK] Etanercept
# Etanercept
# [CHECK] Adalimumab
# Adalimumab
# [CHECK] Infliximab
# Infliximab
# [CHECK] Lenalidomide
# Lenalidomide
# [CHECK] Thalidomide
# Thalidomide
# [CHECK] Nafamostat
# Nafamostat
# [CHECK] Emapalumab
# Emapalumab
# [CHECK] Glucosamine
# Glucosamine
# [CHECK] Rilonacept
# Rilonacept
# [CHECK] Gallium nitrate
# Gallium_nitrate
# [CHECK] Canakinumab
# Canakinumab
# [CHECK] Ibalizumab
# Ibalizumab
# [CHECK] Lanadelumab
# Lanadelumab
# [CHECK] Berotralstat
# Berotralstat
# [CHECK] Ecallantide
# Ecallantide
# [CHECK] Sodium Tetradecyl Sulfate
# Sodium_Tetradecyl_Sulfate
# [CHECK] Mepolizumab
# Mepolizumab
# [CHECK] Reslizumab
# Reslizumab
# [CHECK] Benralizumab
# Benralizumab
# [CHECK] Siltuximab
# Siltuximab
# [CHECK] Hexafluronium bromide
# Hexafluronium_bromide
# [CHECK] MEPTAZINOL
# MEPTAZINOL
# [CHECK] Pegunigalsidase alfa
# Pegunigalsidase_alfa
# [CHECK] Migalastat
# Migalastat
# [CHECK] Etonogestrel
# Etonogestrel
# [CHECK] Megestrol
# Megestrol
# [CHECK] Desogestrel
# Desogestrel
# [CHECK] Estradiol valerate/dienogest
# Estradiol_valerate_dienogest
# [CHECK] Progesterone
# Progesterone
# [CHECK] Norgestimate
# Norgestimate
# [CHECK] Levonorgestrel
# Levonorgestrel
# [CHECK] Dydrogesterone
# Dydrogesterone
# [CHECK] Norethindrone
# Norethindrone
# [CHECK] Medroxyprogesterone
# Medroxyprogesterone
# [CHECK] Ethynodiol Diacetate
# Ethynodiol_Diacetate
# [CHECK] Ulipristal
# Ulipristal
# [CHECK] Segesterone acetate; ethinyl estradiol
# Segesterone_acetate;_ethinyl_estradiol
# [CHECK] Gemfibrozil
# Gemfibrozil
# [CHECK] Clofibrate
# Clofibrate
# [CHECK] L-Tyrosine
# L-Tyrosine
# [CHECK] Metyrosine
# Metyrosine
# [CHECK] Tetrahydrobiopterin
# Tetrahydrobiopterin
# [CHECK] L-Phenylalanine
# L-Phenylalanine
# [CHECK] Carbimazole
# Carbimazole
# [CHECK] Methimazole
# Methimazole
# [CHECK] Propylthiouracil
# Propylthiouracil
# [CHECK] Gallamine Triethiodide
# Gallamine_Triethiodide
# [CHECK] Tropicamide
# Tropicamide
# [CHECK] Diphenidol
# Diphenidol
# [CHECK] Desoxycorticosterone Acetate
# Desoxycorticosterone_Acetate
# [CHECK] Spironolactone
# Spironolactone
# [CHECK] Finerenone
# Finerenone
# [CHECK] Eplerenone
# Eplerenone
# [CHECK] Desoxycorticosterone Pivalate
# Desoxycorticosterone_Pivalate
# [CHECK] Drospirenone
# Drospirenone
# [CHECK] Aldosterone
# Aldosterone
# [CHECK] Ibuprofen
# Ibuprofen
# [CHECK] GDC-0199
# GDC-0199
# [CHECK] MCI-186
# MCI-186
# [CHECK] Taxol
# Taxol
# [CHECK] Fesoterodine fumarate
# Fesoterodine_fumarate
# [CHECK] Cycrimine
# Cycrimine
# [CHECK] Dicyclomine
# Dicyclomine
# [CHECK] Biperiden
# Biperiden
# [CHECK] Oxyphenonium
# Oxyphenonium
# [CHECK] Benztropine
# Benztropine
# [CHECK] Glycopyrrolate
# Glycopyrrolate
# [CHECK] Metixene
# Metixene
# [CHECK] Diphemanil Methylsulfate
# Diphemanil_Methylsulfate
# [CHECK] Pirenzepine
# Pirenzepine
# [CHECK] Propantheline
# Propantheline
# [CHECK] Trihexyphenidyl
# Trihexyphenidyl
# [CHECK] Clidinium
# Clidinium
# [CHECK] Mycophenolate mofetil
# Mycophenolate_mofetil
# [CHECK] Trifarotene
# Trifarotene
# [CHECK] Tazarotene
# Tazarotene
# [CHECK] Palovarotene
# Palovarotene
# [CHECK] Tretinoin
# Tretinoin
# [CHECK] Alitretinoin
# Alitretinoin
# [CHECK] Monobenzone
# Monobenzone
# [CHECK] Hydroquinone
# Hydroquinone
# [CHECK] Bacitracin
# Bacitracin
# [CHECK] Anakinra
# Anakinra
# [CHECK] L-Tryptophan
# L-Tryptophan
# [CHECK] Dalbavancin
# Dalbavancin
# [CHECK] Orlistat
# Orlistat
# [CHECK] Ipilimumab
# Ipilimumab
# [CHECK] Tremelimumab
# Tremelimumab
# [CHECK] Darbepoetin alfa
# Darbepoetin_alfa
# [CHECK] Epoetin alfa
# Epoetin_alfa
# [CHECK] Methoxy polyethylene glycol-epoetin beta
# Methoxy_polyethylene_glycol-epoetin_beta
# [CHECK] RHuEPO
# RHuEPO
# [CHECK] Moxetumomab pasudotox
# Moxetumomab_pasudotox
# [CHECK] Inotuzumab ozogamicin
# Inotuzumab_ozogamicin
# [CHECK] OspA lipoprotein
# OspA_lipoprotein
# [CHECK] Efalizumab
# Efalizumab
# [CHECK] lifitegrast
# lifitegrast
# [CHECK] SR141716A
# SR141716A
# [CHECK] Marinol
# Marinol
# [CHECK] Ridogrel
# Ridogrel
# [CHECK] Alprostadil
# Alprostadil
# [CHECK] Clotrimazole
# Clotrimazole
# [CHECK] Rolapitant
# Rolapitant
# [CHECK] Aprepitant
# Aprepitant
# [CHECK] Palonosetron + fosnetupitant
# Palonosetron_+_fosnetupitant
# [CHECK] Selegiline
# Selegiline
# [CHECK] Ticlopidine
# Ticlopidine
# [CHECK] Vorapaxar
# Vorapaxar
# [CHECK] Quazepam
# Quazepam
# [CHECK] Temazepam
# Temazepam
# [CHECK] Chlordiazepoxide
# Chlordiazepoxide
# [CHECK] Fludiazepam
# Fludiazepam
# [CHECK] Eszopiclone
# Eszopiclone
# [CHECK] Diazepam
# Diazepam
# [CHECK] Flurazepam
# Flurazepam
# [CHECK] Oxazepam
# Oxazepam
# [CHECK] Lorazepam
# Lorazepam
# [CHECK] Adinazolam
# Adinazolam
# [CHECK] Prazepam
# Prazepam
# [CHECK] Alprazolam
# Alprazolam
# [CHECK] Estazolam
# Estazolam
# [CHECK] Clorazepate
# Clorazepate
# [CHECK] Cinolazepam
# Cinolazepam
# [CHECK] Clotiazepam
# Clotiazepam
# [CHECK] Chlormezanone
# Chlormezanone
# [CHECK] Triazolam
# Triazolam
# [CHECK] Midazolam
# Midazolam
# [CHECK] Flunitrazepam
# Flunitrazepam
# [CHECK] Halazepam
# Halazepam
# [CHECK] Alpidem
# Alpidem
# [CHECK] Flumazenil
# Flumazenil
# [CHECK] protirelin
# protirelin
# [CHECK] Telavancin
# Telavancin
# [CHECK] Felypressin
# Felypressin
# [CHECK] Terlipressin
# Terlipressin
# [CHECK] Conivaptan
# Conivaptan
# [CHECK] Mozavaptan
# Mozavaptan
# [CHECK] Oxytocin
# Oxytocin
# [CHECK] Desmopressin
# Desmopressin
# [CHECK] Topiramate
# Topiramate
# [CHECK] Acitretin
# Acitretin
# [CHECK] Cinacalcet
# Cinacalcet
# [CHECK] Etelcalcetide
# Etelcalcetide
# [CHECK] Treprostinil
# Treprostinil
# [CHECK] Dinoprost Tromethamine
# Dinoprost_Tromethamine
# [CHECK] Misoprostol
# Misoprostol
# [CHECK] Selexipag
# Selexipag
# [CHECK] Epoprostenol
# Epoprostenol
# [CHECK] Exenatide
# Exenatide
# [CHECK] Semaglutide
# Semaglutide
# [CHECK] Liraglutide
# Liraglutide
# [CHECK] Dulaglutide
# Dulaglutide
# [CHECK] Lixisenatide
# Lixisenatide
# [CHECK] Pramlintide
# Pramlintide
# [CHECK] Albiglutide
# Albiglutide
# [CHECK] Tirzepatide
# Tirzepatide
# [CHECK] Glucagon recombinant
# Glucagon_recombinant
# [CHECK] Dasiglucagon
# Dasiglucagon
# [CHECK] Allopurinol
# Allopurinol
# [CHECK] Fosdenopterin
# Fosdenopterin
# [CHECK] Febuxostat
# Febuxostat
# [CHECK] Vitamin A
# Vitamin_A
# [CHECK] Cerulenin
# Cerulenin
# [CHECK] Amodiaquine
# Amodiaquine
# [CHECK] Plerixafor
# Plerixafor
# [CHECK] Motixafortide
# Motixafortide
# [CHECK] Cycloserine
# Cycloserine
# [CHECK] Isovanillin
# Isovanillin
# [CHECK] Menadione
# Menadione
# [CHECK] Glycine
# Glycine
# [CHECK] Alpha 1-PI
# Alpha_1-PI
# [CHECK] Brivaracetam
# Brivaracetam
# [CHECK] Levetiracetam
# Levetiracetam
# [CHECK] REGN-727
# REGN-727
# [CHECK] Evolocumab
# Evolocumab
# [CHECK] Tbo-Filgrastim
# Tbo-Filgrastim
# [CHECK] Pegfilgrastim
# Pegfilgrastim
# [CHECK] Pegaptanib
# Pegaptanib
# [CHECK] Suvorexant
# Suvorexant
# [CHECK] Ardeparin
# Ardeparin
# [CHECK] Heparin Calcium
# Heparin_Calcium
# [CHECK] Sulodexide
# Sulodexide
# [CHECK] Heparin Sodium
# Heparin_Sodium
# [CHECK] Glassia
# Glassia
# [CHECK] Zemaira
# Zemaira
# [CHECK] Porfimer Sodium
# Porfimer_Sodium
# [CHECK] Talimogene Laherparepvec
# Talimogene_Laherparepvec
# [CHECK] Paramethasone
# Paramethasone
# [CHECK] Alclometasone
# Alclometasone
# [CHECK] Ciclesonide
# Ciclesonide
# [CHECK] Pentosan Polysulfate
# Pentosan_Polysulfate
# [CHECK] Sucralfate
# Sucralfate
# [CHECK] Burosumab
# Burosumab
# [CHECK] Levothyroxine
# Levothyroxine
# [CHECK] Liothyronine
# Liothyronine
# [CHECK] Dextrothyroxine Sodium
# Dextrothyroxine_Sodium
# [CHECK] Methoxsalen
# Methoxsalen
# [CHECK] Aminolevulinic acid hci
# Aminolevulinic_acid_hci
# [CHECK] Pyrimethamine
# Pyrimethamine
# [CHECK] Mirvetuximab soravtansine
# Mirvetuximab_soravtansine
# [CHECK] Ranibizumab
# Ranibizumab
# [CHECK] Bevacizumab
# Bevacizumab
# [CHECK] Brolucizumab
# Brolucizumab
# [CHECK] Faricimab
# Faricimab
# [CHECK] Aflibercept
# Aflibercept
# [CHECK] Thyrotropin
# Thyrotropin
# [CHECK] Thyrotropin Alfa
# Thyrotropin_Alfa
# [CHECK] Bexarotene
# Bexarotene
# [CHECK] Mizoribine
# Mizoribine
# [CHECK] Ribavirin
# Ribavirin
# [CHECK] Tiazofurin
# Tiazofurin
# [CHECK] Mercaptopurine
# Mercaptopurine
# [CHECK] Betazole
# Betazole
# [CHECK] Cimetidine
# Cimetidine
# [CHECK] Ranitidine
# Ranitidine
# [CHECK] Famotidine
# Famotidine
# [CHECK] Nizatidine
# Nizatidine
# [CHECK] Icatibant
# Icatibant
# [CHECK] Tolvaptan
# Tolvaptan
# [CHECK] Vasopressin
# Vasopressin
# [CHECK] Lutetium Lu 177 dotatate
# Lutetium_Lu_177_dotatate
# [CHECK] Pasireotide
# Pasireotide
# [CHECK] Octreotide
# Octreotide
# [CHECK] Lanreotide acetate
# Lanreotide_acetate
# [CHECK] Ga-68-DOTATOC
# Ga-68-DOTATOC
# [CHECK] Copper dotatate Cu-64
# Copper_dotatate_Cu-64
# [CHECK] Ganirelix
# Ganirelix
# [CHECK] Abarelix
# Abarelix
# [CHECK] Triptorelin
# Triptorelin
# [CHECK] Leuprorelin acetate
# Leuprorelin_acetate
# [CHECK] Gonadorelin
# Gonadorelin
# [CHECK] Nafarelin
# Nafarelin
# [CHECK] Cetrorelix
# Cetrorelix
# [CHECK] Relugolix
# Relugolix
# [CHECK] Elagolix sodium
# Elagolix_sodium
# [CHECK] Degarelix
# Degarelix
# [CHECK] Niflumic Acid
# Niflumic_Acid
# [CHECK] Celecoxib
# Celecoxib
# [CHECK] Lumiracoxib
# Lumiracoxib
# [CHECK] Nabumetone
# Nabumetone
# [CHECK] Mefenamic acid
# Mefenamic_acid
# [CHECK] Rofecoxib
# Rofecoxib
# [CHECK] Phenylbutazone
# Phenylbutazone
# [CHECK] Diflunisal
# Diflunisal
# [CHECK] Tolmetin
# Tolmetin
# [CHECK] Etoricoxib
# Etoricoxib
# [CHECK] Flurbiprofen
# Flurbiprofen
# [CHECK] Meloxicam
# Meloxicam
# [CHECK] Tenoxicam
# Tenoxicam
# [CHECK] Carprofen
# Carprofen
# [CHECK] Valdecoxib
# Valdecoxib
# [CHECK] Etodolac
# Etodolac
# [CHECK] Indomethacin
# Indomethacin
# [CHECK] Tiaprofenic acid
# Tiaprofenic_acid
# [CHECK] Ketoprofen
# Ketoprofen
# [CHECK] Eltrombopag
# Eltrombopag
# [CHECK] Revolade/Promacta
# Revolade_Promacta
# [CHECK] Lusutrombopag
# Lusutrombopag
# [CHECK] AS-1670542
# AS-1670542
# [CHECK] Tafluprost
# Tafluprost
# [CHECK] BOL-303259-X
# BOL-303259-X
# [CHECK] Carboprost Tromethamine
# Carboprost_Tromethamine
# [CHECK] Travoprost
# Travoprost
# [CHECK] Latanoprost
# Latanoprost
# [CHECK] Dinoprostone
# Dinoprostone
# [CHECK] Mogamulizumab
# Mogamulizumab
# [CHECK] Aldesleukin
# Aldesleukin
# [CHECK] Daclizumab
# Daclizumab
# [CHECK] CNTO-1959
# CNTO-1959
# [CHECK] Risankizumab
# Risankizumab
# [CHECK] Tildrakizumab
# Tildrakizumab
# [CHECK] Ustekinumab
# Ustekinumab
# [CHECK] BENZYL BENZOATE
# BENZYL_BENZOATE
# [CHECK] Adenosine monophosphate
# Adenosine_monophosphate
# [CHECK] Nivolumab
# Nivolumab
# [CHECK] Tislelizumab
# Tislelizumab
# [CHECK] MK-3475
# MK-3475
# [CHECK] Pembrolizumab
# Pembrolizumab
# [CHECK] Cemiplimab
# Cemiplimab
# [CHECK] Retifanlimab
# Retifanlimab
# [CHECK] Toripalimab
# Toripalimab
# [CHECK] Sintilimab
# Sintilimab
# [CHECK] Dostarlimab
# Dostarlimab
# [CHECK] Miglustat
# Miglustat
# [CHECK] Eliglustat tartrate
# Eliglustat_tartrate
# [CHECK] Prasugrel
# Prasugrel
# [CHECK] Cangrelor
# Cangrelor
# [CHECK] Clopidogrel
# Clopidogrel
# [CHECK] Brilinta
# Brilinta
# [CHECK] Imiquimod
# Imiquimod
# [CHECK] Hydroxychloroquine
# Hydroxychloroquine
# [CHECK] Avelumab
# Avelumab
# [CHECK] Durvalumab
# Durvalumab
# [CHECK] RG-7446
# RG-7446
# [CHECK] Bavencio
# Bavencio
# [CHECK] Atezolizumab
# Atezolizumab
# [CHECK] Sugemalimab
# Sugemalimab
# [CHECK] Teduglutide
# Teduglutide
# [CHECK] Vestronidase alfa
# Vestronidase_alfa
# [CHECK] Belatacept
# Belatacept
# [CHECK] Carbetocin
# Carbetocin
# [CHECK] Lubiprostone
# Lubiprostone
# [CHECK] Cysteamine
# Cysteamine
# [CHECK] Sermorelin
# Sermorelin
# [CHECK] Tesamorelin
# Tesamorelin
# [CHECK] Probenecid
# Probenecid
# [CHECK] FLUORESCEIN
# FLUORESCEIN
# [CHECK] Vitamin B3
# Vitamin_B3
# [CHECK] Lisdexamfetamine
# Lisdexamfetamine
# [CHECK] Amphetamine
# Amphetamine
# [CHECK] Dextroamphetamine
# Dextroamphetamine
# [CHECK] Hydroxyamphetamine Hydrobromide
# Hydroxyamphetamine_Hydrobromide
# [CHECK] Patisiran
# Patisiran
# [CHECK] Eplontersen
# Eplontersen
# [CHECK] Vutrisiran
# Vutrisiran
# [CHECK] Inotersen
# Inotersen
# [CHECK] Fomepizole
# Fomepizole
# [CHECK] Promazine
# Promazine
# [CHECK] Umeclidinium
# Umeclidinium
# [CHECK] Cimetropium bromide
# Cimetropium_bromide
# [CHECK] Butylscopolamine
# Butylscopolamine
# [CHECK] Trospium
# Trospium
# [CHECK] Pilocarpine
# Pilocarpine
# [CHECK] Choline alfoscerate
# Choline_alfoscerate
# [CHECK] Anisotropine Methylbromide
# Anisotropine_Methylbromide
# [CHECK] Bethanechol
# Bethanechol
# [CHECK] Cyclopentolate
# Cyclopentolate
# [CHECK] Oxitropium bromide
# Oxitropium_bromide
# [CHECK] Prifinium
# Prifinium
# [CHECK] Cryptenamine Acetates
# Cryptenamine_Acetates
# [CHECK] Mepenzolate
# Mepenzolate
# [CHECK] Oxyphencyclimine
# Oxyphencyclimine
# [CHECK] Flutropium bromide
# Flutropium_bromide
# [CHECK] Methantheline
# Methantheline
# [CHECK] Belladonna
# Belladonna
# [CHECK] Flavoxate
# Flavoxate
# [CHECK] Homatropine Methylbromide
# Homatropine_Methylbromide
# [CHECK] Tridihexethyl
# Tridihexethyl
# [CHECK] Pramiracetam
# Pramiracetam
# [CHECK] Ispaghula
# Ispaghula
# [CHECK] Procyclidine
# Procyclidine
# [CHECK] Hyoscyamine
# Hyoscyamine
# [CHECK] Atropine
# Atropine
# [CHECK] Propiverine
# Propiverine
# [CHECK] Mebeverine
# Mebeverine
# [CHECK] Emepronium
# Emepronium
# [CHECK] Anisodine
# Anisodine
# [CHECK] Secretin
# Secretin
# [CHECK] Dapagliflozin
# Dapagliflozin
# [CHECK] Empagliflozin
# Empagliflozin
# [CHECK] Canagliflozin
# Canagliflozin
# [CHECK] PF-04971729
# PF-04971729
# [CHECK] Sotagliflozin
# Sotagliflozin
# [CHECK] Aminolevulinic Acid Hydrochloride
# Aminolevulinic_Acid_Hydrochloride
# [CHECK] Amiloride
# Amiloride
# [CHECK] Tapinarof
# Tapinarof
# [CHECK] Ruxolitinib
# Ruxolitinib
# [CHECK] Ravulizumab
# Ravulizumab
# [CHECK] Zilucoplan
# Zilucoplan
# [CHECK] Pozelimab
# Pozelimab
# [CHECK] Avacincaptad pegol
# Avacincaptad_pegol
# [CHECK] Netarsudil
# Netarsudil
# [CHECK] Methotrexate
# Methotrexate
# [CHECK] Folic Acid
# Folic_Acid
# [CHECK] Capivasertib
# Capivasertib
# [CHECK] Avalglucosidase alfa
# Avalglucosidase_alfa
# [CHECK] Belumosudil
# Belumosudil
# [CHECK] Tralokinumab
# Tralokinumab
# [CHECK] Pitolisant
# Pitolisant
# [CHECK] Pegcetacoplan
# Pegcetacoplan
# [CHECK] Pexidartinib
# Pexidartinib
# [CHECK] Crizanlizumab
# Crizanlizumab
# [CHECK] Fezolinetant
# Fezolinetant
# [CHECK] Tenapanor
# Tenapanor
# [CHECK] Omaveloxolone
# Omaveloxolone
# [CHECK] Tisotumab vedotin
# Tisotumab_vedotin
# [CHECK] Odevixibat
# Odevixibat
# [CHECK] Maralixibat
# Maralixibat
# [CHECK] Bulevirtide
# Bulevirtide
# [CHECK] Zolgensma
# Zolgensma
# [CHECK] Iptacopan
# Iptacopan
# [CHECK] Bempedoic acid
# Bempedoic_acid
# [CHECK] Mitapivat
# Mitapivat
# [CHECK] Olipudase alfa
# Olipudase_alfa
# [CHECK] Velmanase alfa
# Velmanase_alfa
# [CHECK] Ocriplasmin
# Ocriplasmin
# [CHECK] Trumenba
# Trumenba
# [CHECK] Fluvoxamine
# Fluvoxamine
# [CHECK] Vortioxetine
# Vortioxetine
# [CHECK] Nortriptyline
# Nortriptyline
# [CHECK] Chlorphentermine Hydrochloride
# Chlorphentermine_Hydrochloride
# [CHECK] Tianeptine
# Tianeptine
# [CHECK] Paroxetine
# Paroxetine
# [CHECK] Escitalopram
# Escitalopram
# [CHECK] Sertraline
# Sertraline
# [CHECK] Luvox
# Luvox
# [CHECK] Desvenlafaxine
# Desvenlafaxine
# [CHECK] Fluoxetine
# Fluoxetine
# [CHECK] Citalopram
# Citalopram
# [CHECK] Clomipramine
# Clomipramine
# [CHECK] Dextromethorphan Polistirex
# Dextromethorphan_Polistirex
# [CHECK] Trazodone
# Trazodone
# [CHECK] Duloxetine
# Duloxetine
# [CHECK] Levomilnacipran
# Levomilnacipran
# [CHECK] Sibutramine
# Sibutramine
# [CHECK] Amfepramone
# Amfepramone
# [CHECK] Venlafaxine
# Venlafaxine
# [CHECK] Bupropion
# Bupropion
# [CHECK] Vilazodone
# Vilazodone
# [CHECK] Amitriptyline
# Amitriptyline
# [CHECK] Cocaine
# Cocaine
# [CHECK] Acetaminophen
# Acetaminophen
# [CHECK] Dasotraline
# Dasotraline
# [CHECK] Opicapone
# Opicapone
# [CHECK] Entacapone
# Entacapone
# [CHECK] Tolcapone
# Tolcapone
# [CHECK] Pseudoephedrine
# Pseudoephedrine
# [CHECK] Pimozide
# Pimozide
# [CHECK] Risperidone
# Risperidone
# [CHECK] Phentolamine
# Phentolamine
# [CHECK] Carphenazine
# Carphenazine
# [CHECK] Bevantolol
# Bevantolol
# [CHECK] Chlorpromazine
# Chlorpromazine
# [CHECK] Perphenazine
# Perphenazine
# [CHECK] Droperidol
# Droperidol
# [CHECK] Amisulpride
# Amisulpride
# [CHECK] Sulpiride
# Sulpiride
# [CHECK] Tolazoline
# Tolazoline
# [CHECK] Mesoridazine
# Mesoridazine
# [CHECK] Cabergoline
# Cabergoline
# [CHECK] Metaraminol
# Metaraminol
# [CHECK] Bromocriptine
# Bromocriptine
# [CHECK] Perazine
# Perazine
# [CHECK] Levodopa
# Levodopa
# [CHECK] Metoclopramide
# Metoclopramide
# [CHECK] Levomepromazine
# Levomepromazine
# [CHECK] N-0923
# N-0923
# [CHECK] Molindone
# Molindone
# [CHECK] Piperacetazine
# Piperacetazine
# [CHECK] Domperidone
# Domperidone
# [CHECK] Chlorprothixene
# Chlorprothixene
# [CHECK] Prochlorperazine
# Prochlorperazine
# [CHECK] Methyldopa
# Methyldopa
# [CHECK] Ergonovine
# Ergonovine
# [CHECK] Haloperidol
# Haloperidol
# [CHECK] Thiothixene
# Thiothixene
# [CHECK] Mephentermine
# Mephentermine
# [CHECK] Aripiprazole
# Aripiprazole
# [CHECK] Apomorphine
# Apomorphine
# [CHECK] Quetiapine
# Quetiapine
# [CHECK] Zuclopenthixol
# Zuclopenthixol
# [CHECK] Nemonapride
# Nemonapride
# [CHECK] Docarpamine
# Docarpamine
# [CHECK] Acetophenazine
# Acetophenazine
# [CHECK] Ephedrine
# Ephedrine
# [CHECK] Phenylephrine
# Phenylephrine
# [CHECK] Naphazoline
# Naphazoline
# [CHECK] Denopamine
# Denopamine
# [CHECK] Dapiprazole
# Dapiprazole
# [CHECK] Dopamine
# Dopamine
# [CHECK] Thioridazine
# Thioridazine
# [CHECK] Fluspirilene
# Fluspirilene
# [CHECK] Loxapine
# Loxapine
# [CHECK] Ibopamine hci
# Ibopamine_hci
# [CHECK] Dihydroergotamine
# Dihydroergotamine
# [CHECK] Olanzapine
# Olanzapine
# [CHECK] Dopexamine
# Dopexamine
# [CHECK] Quinagolide
# Quinagolide
# [CHECK] Phenoxybenzamine
# Phenoxybenzamine
# [CHECK] Lisuride
# Lisuride
# [CHECK] Thiethylperazine
# Thiethylperazine
# [CHECK] Lurasidone hydrochloride
# Lurasidone_hydrochloride
# [CHECK] Aniracetam
# Aniracetam
# [CHECK] Tiapride
# Tiapride
# [CHECK] Pergolide
# Pergolide
# [CHECK] Cariprazine
# Cariprazine
# [CHECK] Pramipexole
# Pramipexole
# [CHECK] Iloperidone
# Iloperidone
# [CHECK] OPC-34712
# OPC-34712
# [CHECK] Methamphetamine
# Methamphetamine
# [CHECK] Ziprasidone
# Ziprasidone
# [CHECK] Ropinirole
# Ropinirole
# [CHECK] Dihydroergotoxine
# Dihydroergotoxine
# [CHECK] lumateperone tosylate
# lumateperone_tosylate
# [CHECK] Phenyltoloxamine
# Phenyltoloxamine
# [CHECK] Rasagiline
# Rasagiline
# [CHECK] Indeloxazine
# Indeloxazine
# [CHECK] Selegiline Hydrochloride
# Selegiline_Hydrochloride
# [CHECK] Budipine
# Budipine
# [CHECK] Safinamide
# Safinamide
# [CHECK] Safinamide mesylate
# Safinamide_mesylate
# [CHECK] Sulphadoxine
# Sulphadoxine
# [CHECK] Phenelzine
# Phenelzine
# [CHECK] Pargyline
# Pargyline
# [CHECK] Tranylcypromine
# Tranylcypromine
#
# === DRUGS WITH DIRECT JOINT SIGNAL (MESH CONFIRMED) ===
# - Panitumumab (3 PMIDs)
# - Cetuximab (14 PMIDs)
# - Epidermal growth factor (10 PMIDs)
# - Estrogen (4 PMIDs)
# - Meglitinides (1 PMIDs)
# - Temsirolimus (2 PMIDs)
# - Sirolimus (2 PMIDs)
# - Dexamethasone (2 PMIDs)
# - Testosterone (2 PMIDs)
# - Uridine (1 PMIDs)
# - Pioglitazone (7 PMIDs)
# - Thiazolidinedione (5 PMIDs)
# - Valproate (1 PMIDs)
# - Metformin (50 PMIDs)
# - Thalidomide (1 PMIDs)
# - Orlistat (2 PMIDs)
# - Exenatide (4 PMIDs)
# - Semaglutide (2 PMIDs)
# - Liraglutide (3 PMIDs)
# - Dulaglutide (2 PMIDs)
# - Tirzepatide (2 PMIDs)
# - Allopurinol (1 PMIDs)
# - Bevacizumab (7 PMIDs)
# - Adenosine monophosphate (3 PMIDs)
# - Prasugrel (1 PMIDs)
# - Clopidogrel (1 PMIDs)
# - Pilocarpine (1 PMIDs)
# - Dapagliflozin (3 PMIDs)
# - Empagliflozin (1 PMIDs)
# - Methotrexate (3 PMIDs)
# [OK] wrote C:/Users/Admin/OneDrive - Nanyang Technological University/FYP_DATA/LITERATURE/webscrape_results/drug_mesh_joint_results_test.json and individual text reports in C:/Users/Admin/OneDrive - Nanyang Technological University/FYP_DATA/LITERATURE/webscrape_results/

# %% [markdown]
# ### extract pmid and put into file

# %%
config = load_config()
for pair_cfg in config.get("disease_pairs", []):
    pair_name = pair_cfg.get("name", "unnamed_pair")
    print(f"\n=== Running disease pair: {pair_name} ===")

    
    reports_dir = pair_cfg["reports_dir"]
    qualified_drugs = []
    for filename in os.listdir(reports_dir):
        if not filename.endswith("_report.txt"):
            continue

        filepath = os.path.join(reports_dir, filename)
        with open(filepath, "r", encoding="utf-8") as f:
            content = f.read()

    

        # extract drug name and PMID count
        drug_match = re.search(r"DRUG PATHWAY ANALYSIS REPORT:\s*(.+)", content)
        pmid_match = re.search(r"Total joint-hit PMIDs:\s*(\d+)", content)

        # extract all 6–9 digit numeric sequences (likely PMIDs)
        pmids = re.findall(r"\b\d{6,9}\b", content)

        if drug_match and pmid_match:
            drug = drug_match.group(1).strip()
            pmid_count = int(pmid_match.group(1))
            if pmid_count >= 0:
                qualified_drugs.append((drug, pmid_count, pmids))

    # # sort by PMID count descending
    qualified_drugs.sort(key=lambda x: x[1], reverse=True)

    # print results
    print("=== DRUGS WITH JOINT-HIT PMIDs ===")
    for drug, count, pmids in qualified_drugs:
        print(f"- {drug}: {count} PMIDs")
        print(f"  PMIDs: {', '.join(pmids[:10])}{'...' if len(pmids) > 10 else ''}")

    print(f"\nTotal qualifying drugs for {pair_name}: {len(qualified_drugs)}")

    df = pd.DataFrame(qualified_drugs, columns=["Drug", "PMID Count", "PMIDs"])
    df["PMIDs"] = df["PMIDs"].apply(lambda x: ", ".join(x) if isinstance(x, list) else "")
    initial_pmid_list_path = pair_cfg["initial_pmid_list"] 
    df.to_csv(initial_pmid_list_path, index=False)
    print(f"Qualified drugs saved to {initial_pmid_list_path}")
# Out:
# === Running disease pair: diabetes_crc ===
# === DRUGS WITH JOINT-HIT PMIDs ===
# - METFORMIN: 50 PMIDs
#   PMIDs: 40670504, 40649818, 40572709, 40471238, 40353629, 40299707, 40136342, 40124270, 39994354, 39600254...
# - CETUXIMAB: 14 PMIDs
#   PMIDs: 38763818, 35467766, 35279470, 33741057, 29054804, 27881709, 27681944, 26517691, 26405092, 23921573...
# - EPIDERMAL GROWTH FACTOR: 10 PMIDs
#   PMIDs: 38992135, 36546770, 35888591, 26850678, 26831715, 26517691, 26405092, 22439666, 22210091, 20713879
# - BEVACIZUMAB: 7 PMIDs
#   PMIDs: 41019039, 35888591, 29066701, 26972374, 26517691, 21609927, 18056916
# - PIOGLITAZONE: 7 PMIDs
#   PMIDs: 38378472, 32170185, 29637913, 23345544, 23098518, 22135104, 19139117
# - ADENOSINE TRIPHOSPHATE: 5 PMIDs
#   PMIDs: 37522672, 37442756, 30155759, 29463225, 19383331
# - THIAZOLIDINEDIONE: 5 PMIDs
#   PMIDs: 31887708, 23648711, 19908241, 18930061, 17192841
# - ESTROGEN: 4 PMIDs
#   PMIDs: 39132768, 34529197, 33359221, 32859627
# - EXENATIDE: 4 PMIDs
#   PMIDs: 40437949, 39777709, 27470345, 26536615
# - ADENOSINE MONOPHOSPHATE: 3 PMIDs
#   PMIDs: 37071615, 36143915, 27919208
# - DAPAGLIFLOZIN: 3 PMIDs
#   PMIDs: 37781829, 31979355, 26522271
# - LIRAGLUTIDE: 3 PMIDs
#   PMIDs: 40437949, 39777709, 26833744
# - METHOTREXATE: 3 PMIDs
#   PMIDs: 24909934, 17334666, 9470854
# - PANITUMUMAB: 3 PMIDs
#   PMIDs: 33741057, 22210091, 20713879
# - TROGLITAZONE: 3 PMIDs
#   PMIDs: 32170185, 19908241, 10984506
# - DEXAMETHASONE: 2 PMIDs
#   PMIDs: 33722701, 16284058
# - DULAGLUTIDE: 2 PMIDs
#   PMIDs: 40437949, 39777709
# - LETROZOLE: 2 PMIDs
#   PMIDs: 31402321, 26850678
# - ORLISTAT: 2 PMIDs
#   PMIDs: 26284613, 22046255
# - PEMBROLIZUMAB: 2 PMIDs
#   PMIDs: 35427833, 32830561
# - PREDNISOLONE: 2 PMIDs
#   PMIDs: 32378178, 17334666
# - SEMAGLUTIDE: 2 PMIDs
#   PMIDs: 40437949, 39777709
# - SIROLIMUS: 2 PMIDs
#   PMIDs: 37442756, 20430774
# - TEMSIROLIMUS: 2 PMIDs
#   PMIDs: 23982248, 20430774
# - TESTOSTERONE: 2 PMIDs
#   PMIDs: 20309918, 3917360
# - TIRZEPATIDE: 2 PMIDs
#   PMIDs: 40125821, 39777709
# - ACETAMINOPHEN: 1 PMIDs
#   PMIDs: 35839363
# - ALBIGLUTIDE: 1 PMIDs
#   PMIDs: 39777709
# - ALLOPURINOL: 1 PMIDs
#   PMIDs: 31601586
# - ALOGLIPTIN: 1 PMIDs
#   PMIDs: 31955260
# - AMPHETAMINE: 1 PMIDs
#   PMIDs: 39287256
# - ANAGLIPTIN: 1 PMIDs
#   PMIDs: 31955260
# - CELECOXIB: 1 PMIDs
#   PMIDs: 36367997
# - CIMETIDINE: 1 PMIDs
#   PMIDs: 12938277
# - CLOPIDOGREL: 1 PMIDs
#   PMIDs: 23369842
# - DOPAMINE: 1 PMIDs
#   PMIDs: 26808354
# - DULOXETINE: 1 PMIDs
#   PMIDs: 35839363
# - EMPAGLIFLOZIN: 1 PMIDs
#   PMIDs: 31979355
# - ERLOTINIB: 1 PMIDs
#   PMIDs: 26831715
# - ESTRADIOL: 1 PMIDs
#   PMIDs: 39132768
# - EVEROLIMUS: 1 PMIDs
#   PMIDs: 18332469
# - FENOFIBRATE: 1 PMIDs
#   PMIDs: 38763818
# - FOLIC ACID: 1 PMIDs
#   PMIDs: 38262488
# - GLUCOSAMINE: 1 PMIDs
#   PMIDs: 22114026
# - HYDROXYCHLOROQUINE: 1 PMIDs
#   PMIDs: 33608672
# - IBUPROFEN: 1 PMIDs
#   PMIDs: 35839363
# - INDOMETHACIN: 1 PMIDs
#   PMIDs: 17334666
# - LAPATINIB: 1 PMIDs
#   PMIDs: 26850678
# - LENALIDOMIDE: 1 PMIDs
#   PMIDs: 23982248
# - LEUCOVORIN CALCIUM: 1 PMIDs
#   PMIDs: 38763818
# - LINAGLIPTIN: 1 PMIDs
#   PMIDs: 31955260
# - LIXISENATIDE: 1 PMIDs
#   PMIDs: 39777709
# - MARAVIROC: 1 PMIDs
#   PMIDs: 35427833
# - MEGLITINIDES: 1 PMIDs
#   PMIDs: 23137378
# - MERCAPTOPURINE: 1 PMIDs
#   PMIDs: 24030232
# - NANDROLONE: 1 PMIDs
#   PMIDs: 3917360
# - PASIREOTIDE: 1 PMIDs
#   PMIDs: 26808354
# - PILOCARPINE: 1 PMIDs
#   PMIDs: 18056916
# - PRASUGREL: 1 PMIDs
#   PMIDs: 23369842
# - PROGESTERONE: 1 PMIDs
#   PMIDs: 34529197
# - REGORAFENIB: 1 PMIDs
#   PMIDs: 35672730
# - SAXAGLIPTIN: 1 PMIDs
#   PMIDs: 31955260
# - SIBUTRAMINE: 1 PMIDs
#   PMIDs: 22046255
# - SINTILIMAB: 1 PMIDs
#   PMIDs: 41019039
# - SITAGLIPTIN: 1 PMIDs
#   PMIDs: 31955260
# - SORAFENIB: 1 PMIDs
#   PMIDs: 28792505
# - THALIDOMIDE: 1 PMIDs
#   PMIDs: 12663627
# - TRIMETHOPRIM: 1 PMIDs
#   PMIDs: 35672730
# - URIDINE: 1 PMIDs
#   PMIDs: 24283362
# - VALPROATE: 1 PMIDs
#   PMIDs: 29852291
# - VENLAFAXINE: 1 PMIDs
#   PMIDs: 35839363
# - VILDAGLIPTIN: 1 PMIDs
#   PMIDs: 31955260
# - VITAMIN B6: 1 PMIDs
#   PMIDs: 36367997
# - ZANUBRUTINIB: 1 PMIDs
#   PMIDs: 34886775
#
# Total qualifying drugs for diabetes_crc: 74
# Qualified drugs saved to C:/Users/Admin/OneDrive - Nanyang Technological University/FYP_DATA/PROCESSED_DATA/initial_diabetes_crc.csv
